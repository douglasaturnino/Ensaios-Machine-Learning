# %% [markdown]
# ## 0.0 Imports

# %%
import json
import os

import pandas as pd
from sklearn.cluster import KMeans, AffinityPropagation
from sklearn.metrics import silhouette_score

# %% [markdown]
# ## 0.1 Loading Dataset

# %%
home = os.path.dirname(os.getcwd())

data_path = os.path.join(home, 'data', 'X_dataset.csv')

data = pd.read_csv(data_path)

# %%
data.head()
# Out:
#     alcohol  malic_acid       ash  ash_alcanity  magnesium  total_phenols  \
# 0  1.518613    0.191700  0.232053     -1.169593   1.913905       0.627586
# 1  0.246290    0.205534 -0.827996     -2.490847   0.018145       0.575862
# 2  0.196879    0.320158  1.109334     -0.268738   0.088358       0.627586
# 3  1.691550    0.239130  0.487926     -0.809251   0.930918       0.989655
# 4  0.295700    0.365613  1.840403      0.451946   1.281985       0.627586
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity  \
# 0    0.573840             -0.659563         1.224884         0.251717
# 1    0.510549             -0.820719        -0.544721        -0.293321
# 2    0.611814             -0.498407         2.135968         0.269020
# 3    0.664557             -0.981875         1.032155         1.186068
# 4    0.495781              0.226796         0.401404        -0.319276
#
#         hue     od280   proline
# 0  0.455285  0.970696  0.561341
# 1  0.463415  0.780220  0.550642
# 2  0.447154  0.695971  0.646933
# 3  0.308943  0.798535  0.857347
# 4  0.455285  0.608059  0.325963

# %% [markdown]
# ## 0.2 Help Function

# %%
def classifier_evaluetion(model, param):

    model = model(**param)

    labels = model.fit_predict(data)
    
    metric = get_metric(data,labels)

    result = pd.DataFrame({
        'name': model.__class__.__name__,
        'silhouette_score': metric,
        'param': json.dumps(param)
    },index=[0])

    return result


def get_metric(data,labels):
    metric = silhouette_score(data, labels)
    return metric

# %% [markdown]
# # 1.0 K-Means

# %%
result_km = pd.DataFrame()

for i in range(2, 20, 1):
    # Define
    model = KMeans
    param= {
        'n_clusters': i
    }

    result = classifier_evaluetion(model, param)

    result_km = pd.concat([result_km, result]).reset_index(drop=True)

# %%
result_km
# Out:
#       name  silhouette_score               param
# 0   KMeans          0.214245   {"n_clusters": 2}
# 1   KMeans          0.233105   {"n_clusters": 3}
# 2   KMeans          0.224985   {"n_clusters": 4}
# 3   KMeans          0.208530   {"n_clusters": 5}
# 4   KMeans          0.168120   {"n_clusters": 6}
# 5   KMeans          0.196706   {"n_clusters": 7}
# 6   KMeans          0.185310   {"n_clusters": 8}
# 7   KMeans          0.176401   {"n_clusters": 9}
# 8   KMeans          0.175874  {"n_clusters": 10}
# 9   KMeans          0.171391  {"n_clusters": 11}
# 10  KMeans          0.170859  {"n_clusters": 12}
# 11  KMeans          0.166968  {"n_clusters": 13}
# 12  KMeans          0.180291  {"n_clusters": 14}
# 13  KMeans          0.167783  {"n_clusters": 15}
# 14  KMeans          0.135296  {"n_clusters": 16}
# 15  KMeans          0.162906  {"n_clusters": 17}
# 16  KMeans          0.168734  {"n_clusters": 18}
# 17  KMeans          0.178341  {"n_clusters": 19}

# %% [markdown]
# # 2.0 Affinity Propagation

# %%
result_af = pd.DataFrame()

for i in range(-1, -20, -1):
    # Define
    model = AffinityPropagation
    param= {
        'preference': i
    }

    
    result = classifier_evaluetion(model, param)

    result_af = pd.concat([result_af, result]).reset_index(drop=True)

# %%
result_af
# Out:
#                    name  silhouette_score                param
# 0   AffinityPropagation          0.050588   {"preference": -1}
# 1   AffinityPropagation          0.129858   {"preference": -2}
# 2   AffinityPropagation          0.149879   {"preference": -3}
# 3   AffinityPropagation          0.156879   {"preference": -4}
# 4   AffinityPropagation          0.159334   {"preference": -5}
# 5   AffinityPropagation          0.164841   {"preference": -6}
# 6   AffinityPropagation          0.173583   {"preference": -7}
# 7   AffinityPropagation          0.168146   {"preference": -8}
# 8   AffinityPropagation          0.170898   {"preference": -9}
# 9   AffinityPropagation          0.171268  {"preference": -10}
# 10  AffinityPropagation          0.171793  {"preference": -11}
# 11  AffinityPropagation          0.168958  {"preference": -12}
# 12  AffinityPropagation          0.169388  {"preference": -13}
# 13  AffinityPropagation          0.168930  {"preference": -14}
# 14  AffinityPropagation          0.160996  {"preference": -15}
# 15  AffinityPropagation          0.159898  {"preference": -16}
# 16  AffinityPropagation          0.159898  {"preference": -17}
# 17  AffinityPropagation          0.155490  {"preference": -18}
# 18  AffinityPropagation          0.155490  {"preference": -19}
